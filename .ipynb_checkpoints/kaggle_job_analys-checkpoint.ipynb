# %%
import pandas as pd
import numpy as np
import re

import plotly.express as px
import plotly.graph_objs as go

# %%
df = pd.read_csv('DataAnalyst.csv')

# %% [markdown]
# # Cleaning part

# %%
df.head(11)
# Out:
#     Unnamed: 0                                          Job Title  \
# 0            0  Data Analyst, Center on Immigration and Justic...
# 1            1                               Quality Data Analyst
# 2            2  Senior Data Analyst, Insights & Analytics Team...
# 3            3                                       Data Analyst
# 4            4                             Reporting Data Analyst
# 5            5                                       Data Analyst
# 6            6                       Business/Data Analyst (FP&A)
# 7            7                               Data Science Analyst
# 8            8                                       Data Analyst
# 9            9                      Data Analyst, Merchant Health
# 10          10                                       Data Analyst
#
#                Salary Estimate  \
# 0   $37K-$66K (Glassdoor est.)
# 1   $37K-$66K (Glassdoor est.)
# 2   $37K-$66K (Glassdoor est.)
# 3   $37K-$66K (Glassdoor est.)
# ...

# %%
# as we can see the most importent info here is salary estimate and revenue and both of these info is an object dtype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# ...

# %% [markdown]
# ### Let's prepare data to explore
# 1. Look for the missing values
# 2. Make adjustment - based on what we want to find (our goals here)

# %%
# is there any missing values?
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         1
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %% [markdown]
# ### there is a missing value in Company name, but is it all missing values? Let's dive deeper
# For some reason in this dataset missing value is (-1) - so we would need to make (-1) -> np.nan

# %%
df.head(5)
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %%
# np.where(df == [-1,-1.0,'-1'], np.nan, df)
def f(data):
    return data.replace([-1,-1.0,'-1'] , np.nan , inplace = True)
f(df)

# %%
# Real missing values here:
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Job Title               0
# Salary Estimate         1
# Job Description         0
# Rating                272
# Company Name            1
# Location                0
# Headquarters          172
# Size                  163
# Founded               660
# Type of ownership     163
# Industry              353
# Sector                353
# Revenue               163
# Competitors          1732
# Easy Apply           2173
# dtype: int64

# %% [markdown]
# ### Let's clean each column (the most important ones) one by one
# Job Title, ,Salary Estimate, Job Description, Company name, Size, Revenue, Company Name

# %%
df['Job Title'].value_counts()
# Out:
# Data Analyst                        405
# Senior Data Analyst                  90
# Junior Data Analyst                  30
# Business Data Analyst                28
# Sr. Data Analyst                     21
#                                    ...
# Data Analyst – Level II               1
# Data Analyst/Programmer               1
# Data Services Business Analyst 2      1
# Call Center Data Analyst              1
# Senior Quality Data Analyst           1
# Name: Job Title, Length: 1272, dtype: int64

# %% [markdown]
# ### Job title

# %%
#Job Title seems good
df['Job Title'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Salary Estimate
# 1. It hsa a missing value -> find out why and what can I do with it
# 2. Str format of salary Estimate -> I want to write at least 3 new columns (min max avg) + less or greater than average salary in the US -> then count + highlight high end jobs

# %%
# Salary Estiamte has 1 missing value
df['Salary Estimate'].isnull().sum()
# Out:
# 1

# %%
# row #2149 has a missing Salary Estimate - the question is: are there any other advertisments from this company
df[df['Salary Estimate'].isnull()]
# Out:
#       Unnamed: 0                                  Job Title Salary Estimate  \
# 2149      2149.0  Configuration/Data Management Analyst III             NaN
#
#                                         Job Description  Rating  \
# 2149  Job Description\nPosition Title: Configuration...     4.4
#
#          Company Name  Location  Headquarters                 Size  Founded  \
# 2149  Protingent\n4.4  Kent, WA  Bellevue, WA  51 to 200 employees   2001.0
#
#       Type of ownership                Industry             Sector  \
# 2149  Company - Private  Staffing & Outsourcing  Business Services
#
#                        Revenue Competitors Easy Apply
# 2149  $25 to $50 million (USD)         NaN        NaN

# %%
# these jobs are not the same, and thus we are not going to include 2149
df[df['Company Name'] == 'Protingent\n4.4']
# Out:
#       Unnamed: 0                                          Job Title  \
# 2123      2123.0  Engines Configuration and Data Management Analyst
# 2149      2149.0          Configuration/Data Management Analyst III
#
#                   Salary Estimate  \
# 2123  $55K-$101K (Glassdoor est.)
# 2149                          NaN
#
#                                         Job Description  Rating  \
# 2123  Job Description\nPosition Title: Engines Confi...     4.4
# 2149  Job Description\nPosition Title: Configuration...     4.4
#
#          Company Name  Location  Headquarters                 Size  Founded  \
# 2123  Protingent\n4.4  Kent, WA  Bellevue, WA  51 to 200 employees   2001.0
# 2149  Protingent\n4.4  Kent, WA  Bellevue, WA  51 to 200 employees   2001.0
#
#       Type of ownership                Industry             Sector  \
# 2123  Company - Private  Staffing & Outsourcing  Business Services
# 2149  Company - Private  Staffing & Outsourcing  Business Services
#
# ...

# %%
df.drop(2149, inplace = True)

# %%
df['Salary Estimate'].isnull().sum()
# Out:
# 0

# %%
#Another problem with job salary estimates is that it is written in str format -> we need to change it to int format
# There is a min - max - average
df['Salary Estimate'].sample(10)
# Out:
# 905       $29K-$38K (Glassdoor est.)
# 938       $47K-$76K (Glassdoor est.)
# 598      $57K-$103K (Glassdoor est.)
# 403       $48K-$96K (Glassdoor est.)
# 1177     $64K-$113K (Glassdoor est.)
# 1472    $110K-$190K (Glassdoor est.)
# 1515     $89K-$151K (Glassdoor est.)
# 208      $60K-$110K (Glassdoor est.)
# 1961     $93K-$159K (Glassdoor est.)
# 604       $35K-$45K (Glassdoor est.)
# Name: Salary Estimate, dtype: object

# %%
def min_salary(value):
    return value['Salary Estimate'].str.lstrip('$').str[:3].str.replace('K', '').str.strip().astype('float')
def max_salary(value):
    return value['Salary Estimate'].str[6:10].str.replace('K','').str.lstrip('$').str.strip().astype('float')

df.insert(3, 'Salary_min', min_salary(df))
df.insert(4, 'Salary_max', max_salary(df))
df.insert(5, 'Salary_average', df[['Salary_min', 'Salary_max']].mean(axis=1))

# %%
# the average anuual income in the US is 52
across_country = np.where(np.array(df['Salary_average']) > 52, 'greater than average' , 'less than average')
df.insert(6, 'Across_country', across_country)

# %%
# pretty interesting 
df['Across_country'].value_counts()
# Out:
# greater than average    1880
# less than average        372
# Name: Across_country, dtype: int64

# %%
df['Salary_min'].isnull().any()
# Out:
# False

# %%
df['Salary_max'].isnull().any()
# Out:
# False

# %% [markdown]
# ### So far so good:
# 1. Job title is clean - **done**
# 2. Salary estimate - 1 missing value and change from str -> float - **done**

# %% [markdown]
# ### Let's take a look at the job discription column. What am I interested in here:
# 1. Is there any missing value
# 2. How many include SQL, Python (namely Pandas, NumPy, etc.)

# %%
# great - there are no missing values
df['Job Description'].isnull().any()
# Out:
# False

# %%
df['Job Description'].str.contains('Python|python').value_counts()
# Out:
# False    1616
# True      636
# Name: Job Description, dtype: int64

# %%
df['Job Description'].str.contains('SQL').value_counts()
# Out:
# True     1378
# False     874
# Name: Job Description, dtype: int64

# %% [markdown]
# ### Company Name
# 1. Since the company name has some unneccessary info I want ot delte it \nRating
# 2. There is 1 missing value - but we can keep it

# %%
# Something weird here, company name has ratings on it, plus where rating is missed it stays missed in company name
df[['Company Name' , 'Rating']].sample(20)
# Out:
#                                          Company Name  Rating
# 1721                               CSI Tech Inc.\n3.0     3.0
# 1771                               Avacend, Inc.\n2.5     2.5
# 1279                           Kaiser Permanente\n4.0     4.0
# 1254                   22nd Century Technologies\n3.7     3.7
# 2118                   Intelliswift Software Inc\n3.0     3.0
# 1602                                    Fortinet\n4.5     4.5
# 566                                       LACERA\n3.5     3.5
# 2235                       22nd Century Staffing\n4.3     4.3
# 1420                                    Mindteck\n3.3     3.3
# 359                              Barnabas Health\n2.1     2.1
# 290                                       Oracle\n3.6     3.6
# 1655                               Global Resale\n1.9     1.9
# 1327                               Dallas County\n3.1     3.1
# 1013                               Avacend, Inc.\n2.5     2.5
# ...

# %%
df['Company Name'] = df['Company Name'].str.split('\n').str[0]
df.sample(3)
# Out:
#       Unnamed: 0                        Job Title  \
# 567        567.0                     Data Analyst
# 251        251.0  Technical Business/Data Analyst
# 1844      1844.0                     Data Analyst
#
#                   Salary Estimate  Salary_min  Salary_max  Salary_average  \
# 567    $37K-$70K (Glassdoor est.)        37.0        70.0            53.5
# 251   $73K-$127K (Glassdoor est.)        73.0       127.0           100.0
# 1844   $54K-$75K (Glassdoor est.)        54.0        75.0            64.5
#
#             Across_country                                    Job Description  \
# 567   greater than average  Title: Data Analyst\nCompany: Arize Corporatio...
# 251   greater than average  About Capgemini\nCapgemini is a global leader ...
# 1844  greater than average  Job Title:ÂDataÂAnalyst\nLocation: Charlotte, ...
#
#       Rating       Company Name       Location   Headquarters  \
# 567      2.9  Arize Corporation    Anaheim, CA   New York, NY
# ...

# %%
# One company name is missed
df[df['Company Name'].isnull()]
# Out:
#       Unnamed: 0     Job Title             Salary Estimate  Salary_min  \
# 1860      1860.0  Data Analyst  $53K-$99K (Glassdoor est.)        53.0
#
#       Salary_max  Salary_average        Across_country  \
# 1860        99.0            76.0  greater than average
#
#                                         Job Description  Rating Company Name  \
# 1860  Kindred at Home, part of the Kindred at Home f...     NaN          NaN
#
#              Location Headquarters Size  Founded Type of ownership Industry  \
# 1860  Mooresville, NC          NaN  NaN      NaN               NaN      NaN
#
#      Sector Revenue Competitors Easy Apply
# 1860    NaN     NaN         NaN        NaN

# %%
df['Job Description'][1860]
# Out:
# 'Kindred at Home, part of the Kindred at Home family of hospice, home health, palliative, and community care providers, focuses on clinical excellence with compassion and dignity. Our company culture centers around humility, servant leadership, empathy, and innovation while we serve as a leader in the home care industry. Our people and our patient care allow us to make a difference when life matters most. We are passionate about what we do because our care matters.\n\nWe’re looking for a Data Analyst to join our team.\nYou will be responsible for applying forecasting and/or statistical analysis to the company’s sales trends and operational metrics and reporting the results.\nApply forecasting or statistical analysis to company’s sales trends and operational metrics\nGather, organize, analyze, and report operational and sales data\nEvaluate performance metrics to determine acceptable levels of quality or efficiency for various business functions and units\nResearch, compile, assimilat
# ...

# %%
df.drop(['Unnamed: 0'], axis =1, inplace = True)

# %%
df.drop(['Salary Estimate'], axis = 1, inplace = True)

# %% [markdown]
# # Analysis Part

# %%
df_a = df.copy()

# %%
df_a.columns
# Out:
# Index(['Job Title', 'Salary_min', 'Salary_max', 'Salary_average',
#        'Across_country', 'Job Description', 'Rating', 'Company Name',
#        'Location', 'Headquarters', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'Competitors', 'Easy Apply'],
#       dtype='object')

# %%
new_index = ['Job Title', 'Salary_min', 'Salary_max', 'Salary_average', 'Across_country','Rating',  'Company Name',
       'Job Description',
       'Location', 'Headquarters', 'Size', 'Founded', 'Type of ownership',
       'Industry', 'Sector', 'Revenue', 'Competitors', 'Easy Apply']
df_a = df_a.reindex(new_index, axis = 'columns')

# %%
df_a.describe()
# Out:
#         Salary_min   Salary_max  Salary_average       Rating      Founded
# count  2252.000000  2252.000000     2252.000000  1980.000000  1592.000000
# mean     54.266874    89.979130       72.123002     3.731566  1978.348618
# std      19.575375    29.315605       23.600734     0.670333    47.833946
# min      24.000000    38.000000       33.500000     1.000000  1682.000000
# 25%      41.000000    70.000000       58.000000     3.300000  1970.000000
# 50%      50.000000    87.000000       69.000000     3.700000  1997.000000
# 75%      64.000000   104.000000       80.500000     4.100000  2006.000000
# max     113.000000   190.000000      150.000000     5.000000  2019.000000

# %% [markdown]
# ### Let's look at the some of the information we can get from above table:
# 1. Average min salary of data analysit is 54 -> 52 is an average salary in the US
# 2. Average rating is around 3.7
# 3. Average salary of data analysit is 72 -> but it deviates a lot min = 33.5 , max = 150

# %%
px.histogram(df_a, x = 'Across_country',
                  title = 'Average across the country',
                  color_discrete_sequence = ['indianred'])
# Out:
# <div>                            <div id="c2cdbc3c-9895-4995-8f21-581edaace78d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2cdbc3c-9895-4995-8f21-581edaace78d")) {                    Plotly.newPlot(                        "c2cdbc3c-9895-4995-8f21-581edaace78d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Across_country=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"indianred","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["less than average","less than average","less than average","less than average","less than average","less than average","less than average","less than average","less than average","less than average","less than average",
# ...

# %%
new_df_min = pd.DataFrame(df_a['Salary_min'])
new_df_min['Labels'] = 'Salary_min'
new_df_min = new_df_min.rename(columns = {'Salary_min' : 'Salary'})

new_df_max = pd.DataFrame(df_a['Salary_max'])
new_df_max['Labels'] = 'Salary_max'
new_df_max = new_df_max.rename(columns = {'Salary_max' : 'Salary'})

new_df = new_df_min.append(new_df_max, ignore_index = True)

px.histogram(new_df, x="Salary", color="Labels", barmode="overlay", title = 'Min Salary and Max Salary distribution')
# Out:
# <div>                            <div id="80917f25-f4cc-477b-98f1-6c4e4ba01d79" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80917f25-f4cc-477b-98f1-6c4e4ba01d79")) {                    Plotly.newPlot(                        "80917f25-f4cc-477b-98f1-6c4e4ba01d79",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Labels=Salary_min<br>Salary=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Salary_min","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"Salary_min","offsetgroup":"Salary_min","orientation":"v","showlegend":true,"x":[37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,37.0,46.0,46.0,46.0,4
# ...

# %%
new_df = pd.DataFrame(df_a['Job Title'].value_counts().head(15))
new_df = new_df.rename(columns = {'Job Title' : 'Most Popular'})
new_df['Job Title'] = new_df.index
new_df = new_df.set_index(np.arange(15))

# %%
px.line(new_df, x='Job Title', y='Most Popular', markers = True, title = '15 most in demand jobs in data field')
# Out:
# <div>                            <div id="a4c06eec-d9c6-479d-8ddb-c0772e49136b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4c06eec-d9c6-479d-8ddb-c0772e49136b")) {                    Plotly.newPlot(                        "a4c06eec-d9c6-479d-8ddb-c0772e49136b",                        [{"hovertemplate":"Job Title=%{x}<br>Most Popular=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":["Data Analyst","Senior Data Analyst","Junior Data Analyst","Business Data Analyst","Sr. Data Analyst","Data Quality Analyst","Data Analyst Junior","Data Analyst II","Data Governance Analyst","Lead Data Analyst","Data Reporting Analyst
# ...

# %%
px.scatter(df_a, x = 'Salary_min' , y = 'Company Name' , color = 'Rating',
          title = 'Rating to minimum salary ratio')
# Out:
# <div>                            <div id="60d61daf-5aa3-4101-8154-e7c5da041f0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60d61daf-5aa3-4101-8154-e7c5da041f0f")) {                    Plotly.newPlot(                        "60d61daf-5aa3-4101-8154-e7c5da041f0f",                        [{"hovertemplate":"Salary_min=%{x}<br>Company Name=%{y}<br>Rating=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[3.2,3.8,3.4,4.1,3.9,3.9,4.4,3.7,4.0,4.4,4.0,null,3.7,3.0,3.4,3.6,3.8,3.8,3.9,4.9,4.4,null,3.3,3.5,3.8,4.0,5.0,4.8,3.7,4.7,3.6,3.6,3.5,3.2,null,3.7,null,3.6,4.0,4.6,null,null,5.0,4.0,3.0,2.9,4.0,3.6,4.9,3.9,4.0,3.8,3.7,3.6,3.6,null,4.0,3.2,3.8,3.9,4.8,3.6,3.6,3.6,4.1,3.9,3.0,3.7,null,3.9,3.7,null,3.6,3.7,3.6,4.1,3.5,3.7,5.0,4.0,4.8,5
# ...

# %% [markdown]
# # To sum up

# %% [markdown]
# 1. In the US analytics job salary is higher than an average salary
# 2. Median min salary: 54k
# 3. Median max salary: 89k
# 4. Median average salary: 72 -> which is way higher than average salary in the same US
# 5. Data Analyst job is in demand and employers are more interested in finding people with Data Analyst background
# 6. Rating of the company plays less role in regard to salary. Companies with ratings 4 or even 5 are in the buttom of graph distrubution. Whereas, some of the companies with rating less than even 3 are on the top of salary pyramid
